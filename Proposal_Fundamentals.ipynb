# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
df=pd.read_csv('sample_US_Fundamentals.csv')

# %% [markdown]
# ### + 200 fundamentals with Income Statements, Balance Sheet, Cash Flows and associated ratios
# ---

# %%
pd.DataFrame(df.columns.tolist())
# Out:
#                                   0
# 0                        Unnamed: 0
# 1                          m_ticker
# 2                            ticker
# 3                         comp_name
# 4                       comp_name_2
# 5                          exchange
# 6                     currency_code
# 7                      per_end_date
# 8                          per_type
# 9                          per_code
# 10                    per_fisc_year
# 11                     per_fisc_qtr
# 12                     per_cal_year
# 13                      per_cal_qtr
# 14                    data_type_ind
# 15                      filing_type
# 16                          qtr_nbr
# 17                        fye_month
# 18                         comp_cik
# 19                          per_len
# 20                         sic_code
# 21                      filing_date
# 22                last_changed_date
# 23                state_incorp_name
# 24               bus_address_line_1
# ...

# %%
df
# Out:
#     m_ticker ticker        comp_name  \
# 0       AAPL   AAPL        APPLE INC
# 1       AAPL   AAPL        APPLE INC
# 2       AAPL   AAPL        APPLE INC
# 3       AAPL   AAPL        APPLE INC
# 4       AAPL   AAPL        APPLE INC
# 5        AXP    AXP  AMER EXPRESS CO
# 6        AXP    AXP  AMER EXPRESS CO
# 7        AXP    AXP  AMER EXPRESS CO
# 8        AXP    AXP  AMER EXPRESS CO
# 9        AXP    AXP  AMER EXPRESS CO
# 10        BA     BA        BOEING CO
# 11        BA     BA        BOEING CO
# 12        BA     BA        BOEING CO
# 13        BA     BA        BOEING CO
# 14        BA     BA        BOEING CO
# 15       CTR    CAT  CATERPILLAR INC
# 16       CTR    CAT  CATERPILLAR INC
# 17       CTR    CAT  CATERPILLAR INC
# 18       CTR    CAT  CATERPILLAR INC
# 19       CTR    CAT  CATERPILLAR INC
# 20      CSCO   CSCO    CISCO SYSTEMS
# 21      CSCO   CSCO    CISCO SYSTEMS
# 22      CSCO   CSCO    CISCO SYSTEMS
# 23      CSCO   CSCO    CISCO SYSTEMS
# ...

# %% [markdown]
# **Fundamentals for APPLE**
# ---

# %%
df[df['ticker']=='AAPL']
# Out:
#   m_ticker ticker  comp_name comp_name_2 exchange currency_code per_end_date  \
# 0     AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD   2018-09-30
# 1     AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD   2018-03-31
# 2     AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD   2018-06-30
# 3     AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD   2018-09-30
# 4     AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD   2018-12-31
#
#   per_type  per_code  per_fisc_year  per_fisc_qtr  per_cal_year  per_cal_qtr  \
# 0        A       NaN           2018             4          2018            3
# 1        Q       NaN           2018             2          2018            1
# 2        Q       NaN           2018             3          2018            2
# 3        Q       NaN           2018             4          2018            3
# 4        Q       NaN           2019             1          2018            4
#
# ...
